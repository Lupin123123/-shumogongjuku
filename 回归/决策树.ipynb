# %%
from sklearn import tree
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
# import graphviz

# %%
df = pd.read_excel('final file.xlsx')

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
label = enc.fit_transform(df['cixing'])
df['cixing'] = label

# %%
X = df.iloc[:, 1:-1].to_numpy()
y = df.iloc[:,-1].to_numpy()

# %%
y
# Out:
# array([0.09317959, 0.09304848, 0.0959452 , 0.09608135, 0.09636477,
#        0.10209385, 0.10042433, 0.09422612, 0.0962757 , 0.09926794,
#        0.09179441, 0.09367361, 0.09311803, 0.0951006 , 0.09348138,
#        0.09451713, 0.0959145 , 0.09834806, 0.09227833, 0.09399729,
#        0.09454595, 0.09646925, 0.09158206, 0.0878815 , 0.09590747,
#        0.09617593, 0.09502008, 0.09375611, 0.09466762, 0.09506614,
#        0.09722468, 0.09361619, 0.09756098, 0.09535143, 0.09346981,
#        0.09188431, 0.0962516 , 0.0983577 , 0.09192514, 0.09235704,
#        0.09807312, 0.09587451, 0.09697362, 0.09925363, 0.09211724,
#        0.09935095, 0.09645132, 0.09296804, 0.10025912, 0.09553933,
#        0.09379448, 0.09374886, 0.0923958 , 0.09300702, 0.0934626 ,
#        0.09698082, 0.09249235, 0.09385291, 0.09538472, 0.09541019,
#        0.13333576, 0.09706393, 0.10116732, 0.10081094, 0.09446336,
#        0.09471549, 0.09659715, 0.09729562, 0.09562304, 0.10317975,
# ...

# %%
#训练决策树
clf = tree.DecisionTreeRegressor(random_state=0)
clf = clf.fit(X, y)
score = clf.score(X, y)
score
# Out:
# 1.0

# %%
yhat = clf.predict(X)
plt.figure(figsize=(20, 8), dpi=200)
plt.plot(yhat)
plt.plot(y)
score = clf.score(X, yhat)
plt.show()

# %%
score
# Out:
# 1.0

# %%
clf.feature_importances_
# Out:
# array([0.07397136, 0.03735369, 0.47181975, 0.4168552 ])

# %%
# #画出决策树
# feature_name = feature_lst
# feature_name

# %%
# dot_data = tree.export_graphviz(clf
#                                 ,feature_names= feature_name
#                                 ,class_names=["类型一", "类型二"]
#                                 ,filled=True
#                                 ,rounded=True
#                                 )
# graph = graphviz.Source(dot_data)
# graph

# %%
# #观察特征的重要性
# # print(clf.feature_importances_)
# print(pd.DataFrame([*zip(feature_name, clf.feature_importances_)]))  #*zip()：解压

# %%
# from sklearn.model_selection import cross_val_score
# import matplotlib.pyplot as plt
# import seaborn as sns
# from sklearn.ensemble import RandomForestClassifier
# sns.set()

# clf = RandomForestClassifier(n_estimators=500, random_state=0)
# clf_c = cross_val_score(clf, X, y, cv=10)

# sns.lineplot(range(1, 11), clf_c, label="Decision Tree", color='g')

# plt.legend()
# plt.show()
# clf_c.mean()
