# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
# sns.set()
plt.style.use('fivethirtyeight') 
plt.rcParams['font.sans-serif'] = ['fangsong']	# 显示中文
plt.rcParams['axes.unicode_minus'] = False		# 显示负号

# %%
dataset = load_digits()
X = dataset.data
y = dataset.target

# %%
n_clusters = 3
cluster = KMeans(n_clusters=n_clusters, random_state=0).fit(X)

# %% [markdown]
# ## 预测值

# %%
y_pred = cluster.labels_
y_pred
# Out:
# array([2, 1, 1, ..., 1, 0, 0])

# %% [markdown]
# ## 质心

# %%
centroid = cluster.cluster_centers_
centroid
# Out:
# array([[ 0.00000000e+00,  5.27607362e-01,  8.16411043e+00,
#          1.33527607e+01,  1.13834356e+01,  5.27760736e+00,
#          6.65644172e-01,  3.06748466e-03,  1.07361963e-02,
#          3.74079755e+00,  1.32929448e+01,  1.00950920e+01,
#          1.06349693e+01,  8.86809816e+00,  1.11503067e+00,
#          4.60122699e-03,  4.60122699e-03,  3.73159509e+00,
#          9.03680982e+00,  5.04141104e+00,  9.71472393e+00,
#          8.42484663e+00,  1.03834356e+00,  1.04083409e-16,
#         -1.30104261e-18,  1.50153374e+00,  5.90644172e+00,
#          9.52607362e+00,  1.30199387e+01,  7.78680982e+00,
#          1.13036810e+00, -2.60208521e-18,  0.00000000e+00,
#          2.43865031e-01,  2.27914110e+00,  6.61809816e+00,
#          9.38650307e+00,  8.97699387e+00,  2.42024540e+00,
#          0.00000000e+00, -1.04083409e-17,  3.28220859e-01,
#          2.73773006e+00,  3.92177914e+00,  4.37576687e+00,
#          9.29447853e+00,  4.58895706e+00,  1.07361963e-02,
#         -6.07153217e-18,  9.32515337e-01,  8.53067485e+00,
#          7.85276074e+00,  8.11042945e+00,  1.24110429e+01,
#          6.23312883e+00,  3.78834356e-01, -6.50521303e-19,
#          4.76993865e-01,  8.45245399e+00,  1.38757669e+01,
#          1.38680982e+01,  1.01349693e+01,  3.92484663e+00,
#          9.27914110e-01],
#        [ 0.00000000e+00,  3.06501548e-01,  4.65170279e+00,
#          1.11021672e+01,  1.30417957e+01,  8.94117647e+00,
#          3.03250774e+00,  3.56037152e-01,  4.64396285e-03,
#          1.50154799e+00,  9.17492260e+00,  1.23823529e+01,
#          1.12275542e+01,  1.02136223e+01,  3.55263158e+00,
#          2.41486068e-01,  3.09597523e-03,  2.09442724e+00,
#          8.67801858e+00,  7.81269350e+00,  8.56037152e+00,
#          8.97213622e+00,  2.12693498e+00,  7.27554180e-02,
#          3.09597523e-03,  2.26160991e+00,  8.78947368e+00,
#          1.08219814e+01,  1.22600619e+01,  7.79721362e+00,
#          2.10216718e+00,  3.09597523e-03,  0.00000000e+00,
#          1.72600619e+00,  8.49071207e+00,  1.27647059e+01,
#          1.31238390e+01,  6.84520124e+00,  1.80340557e+00,
#          0.00000000e+00, -1.04083409e-17,  1.13931889e+00,
#          6.13467492e+00,  1.01609907e+01,  1.19071207e+01,
#          4.95046440e+00,  4.53560372e-01, -2.42861287e-17,
#          4.64396285e-03,  4.65944272e-01,  5.04643963e+00,
#          1.07523220e+01,  1.05835913e+01,  3.68575851e+00,
#          2.95665635e-01,  1.54798762e-03,  1.54798762e-03,
#          2.87925697e-01,  5.28173375e+00,  1.11021672e+01,
#          8.11300310e+00,  2.83281734e+00,  4.02476780e-01,
#          1.08359133e-02],
#        [ 0.00000000e+00,  8.01603206e-03,  2.05410822e+00,
#          1.08036072e+01,  1.09098196e+01,  2.35070140e+00,
#          1.10220441e-01,  2.00400802e-03,  3.46944695e-18,
#          3.48697395e-01,  8.14228457e+00,  1.39198397e+01,
#          8.58717435e+00,  4.63326653e+00,  5.93186373e-01,
#          7.01402806e-02,  1.73472348e-18,  1.78156313e+00,
#          1.26212425e+01,  8.48096192e+00,  1.78557114e+00,
#          5.48897796e+00,  2.33066132e+00,  8.61723447e-02,
#         -2.16840434e-19,  4.00400802e+00,  1.36432866e+01,
#          5.31062124e+00,  2.86573146e+00,  6.92585170e+00,
#          4.14829659e+00,  4.00801603e-03,  0.00000000e+00,
#          5.87174349e+00,  1.36412826e+01,  7.49699399e+00,
#          7.84368737e+00,  1.08977956e+01,  4.97995992e+00,
#          0.00000000e+00,  3.20641283e-02,  3.79959920e+00,
#          1.32625251e+01,  7.75150301e+00,  6.49699399e+00,
#          1.11082164e+01,  5.86372745e+00,  8.41683367e-02,
#          2.00400802e-02,  7.15430862e-01,  9.35470942e+00,
#          1.01723447e+01,  9.61122244e+00,  1.05531062e+01,
#          4.88777555e+00,  2.46492986e-01, -1.08420217e-19,
#          1.00200401e-02,  2.13226453e+00,  1.10320641e+01,
#          1.39038076e+01,  7.44889780e+00,  1.79759519e+00,
#          8.61723447e-02]])

# %% [markdown]
# ## 可视化

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

embeddings = {
    "t-SNE embeedding": TSNE(
        n_components=2,
        init="pca",
        random_state=0,
    ),
    "PCA embedding" : PCA(n_components=2, random_state=0)
}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
sns.set()


target_names = list(set(y_pred))
def plot_embedding(X, title):
    _, ax = plt.subplots(1, 1, figsize=(10, 8), dpi=100)
    X = MinMaxScaler().fit_transform(X)
    for name in target_names:
        ax.scatter(
            *X[y_pred == name].T,
            marker = f"${name}$",
            s = 60,
            color = plt.cm.Dark2(name),
            alpha = 0.425,
            zorder = 2,
        )
    ax.set_title(title, fontsize=24)
    ax.axes.xaxis.set_ticklabels([])
    ax.axes.yaxis.set_ticklabels([])

# %%
from time import time

projections, timing = {}, {}
for name, transformer in embeddings.items():
    if name.startswith("Linear Discriminant Analysis"):
        data = X.copy()
        data.flat[:: X.shape[1] + 1] += 0.01  # Make X invertible
    else:
        data = X

    print(f"Computing {name}...")
    start_time = time()
    projections[name] = transformer.fit_transform(data)
    timing[name] = time() - start_time
    
for name in timing:
    title = f"{name} (time {timing[name]:.3f}s)"
    plot_embedding(projections[name], title)
plt.show()
# Out:
# Computing t-SNE embeedding...
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# Computing PCA embedding...

# %%
X
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %% [markdown]
# ## 利用轮廓系数选择K

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

for n_clusters in range(2, 15):
    n_clusters = n_clusters
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, X.shape[0] + (n_clusters + 1) * 10])

    clusterer = KMeans(n_clusters=n_clusters, random_state=10).fit(X)
    cluster_labels = clusterer.labels_
    silhouette_avg = silhouette_score(X, cluster_labels)

    ## 可以总结为轮廓系数越接近于1越好，负数则表示聚类效果非常差。
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
    
    sample_silhouette_values = silhouette_samples(X, cluster_labels)
    
    y_lower = 10
    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]
        ith_cluster_silhouette_values.sort()
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i)/n_clusters)

        ax1.fill_betweenx(np.arange(y_lower, y_upper), ith_cluster_silhouette_values, 
                          facecolor=color, alpha=0.7)
        ax1.text(-0.05, y_lower+0.5*size_cluster_i, str(i))

        y_lower = y_upper + 10

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax1.set_yticks([])
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    
    ## 降维
    from sklearn.manifold import TSNE
    X_new = TSNE(n_components=2, random_state=0).fit_transform(X)
    
    ## 绘制降维后的散点图
    ax2.scatter(X_new[:, 0], X_new[:, 1], marker='o', s=8, c=colors)

    # centers = clusterer.cluster_centers_
    # ax2.scatter(centers[:, 0], centers[:, 1], marker='x',
    #             c="red", alpha=1, s=200)
    
    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')
    plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.11832841100655983
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 3 The average silhouette_score is : 0.1265415792194053
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 4 The average silhouette_score is : 0.12801530390921514
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 5 The average silhouette_score is : 0.13717816072927472
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 6 The average silhouette_score is : 0.15115491877067683
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 7 The average silhouette_score is : 0.16177381269483868
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 8 The average silhouette_score is : 0.17880419723273033
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 9 The average silhouette_score is : 0.18914167962876496
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 10 The average silhouette_score is : 0.18240309354827952
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 11 The average silhouette_score is : 0.18270881323070284
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 12 The average silhouette_score is : 0.1831904283719492
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 13 The average silhouette_score is : 0.1853618434787954
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# For n_clusters = 14 The average silhouette_score is : 0.18798716095670537
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# d:\anaconda\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
