# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
###### 数据X，Y，Z
x = np.arange(-10, 10, 0.01) # 步长为0.01，即每隔0.01取一个点
y = np.arange(-10, 10, 0.01) # 步长为0.01，即每隔0.01取一个点
X, Y = np.meshgrid(x, y)     # 将原始数据变成网格数据形式
Z = X**2 + Y**2              # 我们假设Z为关于X，Y的函数，以Z=X^2+Y^2为例

# %%
Z
# Out:
# array([[200.    , 199.8001, 199.6004, ..., 199.4009, 199.6004, 199.8001],
#        [199.8001, 199.6002, 199.4005, ..., 199.201 , 199.4005, 199.6002],
#        [199.6004, 199.4005, 199.2008, ..., 199.0013, 199.2008, 199.4005],
#        ...,
#        [199.4009, 199.201 , 199.0013, ..., 198.8018, 199.0013, 199.201 ],
#        [199.6004, 199.4005, 199.2008, ..., 199.0013, 199.2008, 199.4005],
#        [199.8001, 199.6002, 199.4005, ..., 199.201 , 199.4005, 199.6002]])

# %%
fig, ax = plt.subplots(1, 2)
ax[0].contour(X, Y, Z, 25)      # 画等高线，25：等高线的数目 
ax[1].contourf(X, Y, Z, 25)     # 画等高线，25：等高线的数目
plt.show()
