# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
A = np.arange(1,5)
B = A**2
C = A**3

# %%
fig, ax = plt.subplots(2, 1, figsize=(14,7))
ax[1].plot(A,B)
ax[1].plot(B,A)
